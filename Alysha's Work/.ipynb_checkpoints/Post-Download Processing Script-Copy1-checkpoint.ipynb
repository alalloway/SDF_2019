# %% [markdown]
# # Post Download Processing Script
# This script is intended to process the data from the US Census Geo-Tiger FTP Site. Please note that this script must be run in ArcPro's Jupyter Lab, and not the Anaconda Jupyter Lab in order to successfully import all modules.

# %% [markdown]
# ## Copy shapes to geodatabase

# %%
import os
import sys
import zipfile
import string
import arcpy

#constants
working_directory = r"C:/Users/and04671/Documents/Data_Files"
#this dirs list includes all directories defined in the download script, without 
#additional water/road directories
folders = ['AIANNH','AITSN','ANRC','BG','CBSA','CD','CNECTA','CONCITY','COUNTY',
        'COUSUB','CSA','ELSD','METDIV','NECTA','NECTADIV','PLACE','PUMA',
        'SCSD','SLDL','SLDU','STATE','SUBMCD','TBG','TRACT','TTRACT','UAC',
        'UNSD','ZCTA5',
          
        'AREAWATER','LINEARWATER','COASTLINE','FACES',
        'FACESAH','FACESAL','FACESMIL','FEATNAMES','PRIMARYROADS',
        'PRISECROADS','RAILS','ROADS']

#note that the original folder pulls did not have Division, Nation, Trust, Res Only, Region as these could not be found...
#on the census site

#dirs = ['AIANNH']
#dirs = ['COUSB']
out_db = r"C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb"

#0. get the shapefiles into the geodb, merging shapefiles that come as state-wide extents
#what's the deal with not being able to put slash other way?
for folder in folders:
    shp_dir = working_directory + "/" + folder
    # establish the right'sandbox' to work in
    arcpy.env.workspace = shp_dir
    #compile a lit of all feature classes as defined by arg
    shps = arcpy.ListFeatureClasses("*")
    for shp in shps:
    #if the number of shapefiles in the folder is 1...
    #try len(shps) == 1:
        #the name of the shapefile is shp_dir + first shapefile in folder (the 0th)
        shp_file = shp_dir + "/" + shp
        #shp_name is the first shapefile in folder
        
        #the h disappears before somewhere after this point
        
        shp_name = shp.strip(shp[-3:])
        shp_name = shp_name.strip(".")
        print(shp_name)
        #no H at this point. strange
        
        #name the new out feature class
        
        out_fc = out_db + "/" + shp_name
        print(out_fc)
       # arcpy.CopyFeatures_management(shp_file,out_fc)

    
    
#merge shp option
'''  
    else:
        out_fc = out_db + "tl_2018_us_" + folder.lower()
        arcpy.Merge_management(shps,out_fc)
       '''
# Out:
# tl_2018_us_aiannh
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_us_aiannh
# tl_2018_us_aitsn
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_us_aitsn
# tl_2018_02_anrc
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_02_anrc
# tl_2018_01_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_01_bg
# tl_2018_02_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_02_bg
# tl_2018_04_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_04_bg
# tl_2018_05_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_05_bg
# tl_2018_06_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_06_bg
# tl_2018_08_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_08_bg
# tl_2018_09_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_09_bg
# tl_2018_10_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_10_bg
# tl_2018_11_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_11_bg
# tl_2018_12_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_12_bg
# tl_2018_13_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_13_bg
# tl_2018_15_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_15_bg
# tl_2018_16_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_16_bg
# tl_2018_17_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_17_bg
# tl_2018_18_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_18_bg
# tl_2018_19_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_19_bg
# tl_2018_20_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_20_bg
# tl_2018_21_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_21_bg
# tl_2018_22_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_22_bg
# tl_2018_23_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_23_bg
# tl_2018_24_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_24_bg
# tl_2018_25_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_25_bg
# tl_2018_26_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_26_bg
# tl_2018_27_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_27_bg
# tl_2018_28_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_28_bg
# tl_2018_29_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_29_bg
# tl_2018_30_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_30_bg
# tl_2018_31_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_31_bg
# tl_2018_32_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_32_bg
# tl_2018_33_bg
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_33
tract
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_49_tract
# tl_2018_50_tract
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_50_tract
# tl_2018_51_tract
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_51_tract
# tl_2018_53_tract
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_53_tract
# tl_2018_54_tract
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_54_tract
# tl_2018_55_tract
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_55_tract
# tl_2018_56_tract
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_56_tract
# tl_2018_60_tract
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_60_tract
# tl_2018_66_tract
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_66_tract
# tl_2018_69_tract
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_69_tract
# tl_2018_72_tract
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_72_tract
# tl_2018_78_tract
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_78_tract
# tl_2018_us_ttract
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_us_ttract
# tl_2018_us_uac10
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_us_uac10
# tl_2018_01_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_01_unsd
# tl_2018_02_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_02_unsd
# tl_2018_04_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_04_unsd
# tl_2018_05_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_05_unsd
# tl_2018_06_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_06_unsd
# tl_2018_08_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_08_unsd
# tl_2018_09_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_09_unsd
# tl_2018_10_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_10_unsd
# tl_2018_11_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_11_unsd
# tl_2018_12_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_12_unsd
# tl_2018_13_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_13_unsd
# tl_2018_15_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_15_unsd
# tl_2018_16_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_16_unsd
# tl_2018_17_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_17_unsd
# tl_2018_18_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_18_unsd
# tl_2018_19_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_19_unsd
# tl_2018_20_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_20_unsd
# tl_2018_21_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_21_unsd
# tl_2018_22_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_22_unsd
# tl_2018_23_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_23_unsd
# tl_2018_24_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_24_unsd
# tl_2018_25_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_25_unsd
# tl_2018_26_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_26_unsd
# tl_2018_27_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_27_unsd
# tl_2018_28_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_28_unsd
# tl_2018_29_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_29_unsd
# tl_2018_30_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_30_unsd
# tl_2018_31_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_31_unsd
# tl_2018_32_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_32_unsd
# tl_2018_33_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_33_unsd
# tl_2018_34_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_34_unsd
# tl_2018_35_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_35_unsd
# tl_2018_36_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_36_unsd
# tl_2018_37_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_37_unsd
# tl_2018_38_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_38_unsd
# tl_2018_39_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_39_unsd
# tl_2018_40_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_40_unsd
# tl_2018_41_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_41_unsd
# tl_2018_42_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_42_unsd
# tl_2018_44_unsd
# C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb/tl_2018_44_unsd

# %% [markdown]
# ## Add GISjoin

# %%
import os
import sys
import zipfile
import string
import arcpy
#see GIS JOIN pattern for # reasoning
working_directory = r"C:/Users/and04671/Documents/Data_Files"

out_db = r"C:/Users/and04671/Documents/Data_Files/TIGER2018.gdb"

dir_dict = {'AIANHH':5,'AITSN':8,'ANRC':6,'BG':15,'CBSA':6,'CD115':6,'CNECTA':4,'CONCITY':9,'COUNTY':8,
            'COUSUB':13,'CSA':4,'DIVISION':2,'ELSD':9,'METDIV':11,'NATION':2,'NECTA':6,'NECTADIV':11,
            'PLACE':9,'PUMA':9,'SCSD':9,'SLDL':7,'SLDU':7,'STATE':4,'SUBMCD':13,'TBG':12,'TRACT':14,
            'TTRACT':11,'UAC10':6,'UNSD':9,'ZCTA510':6,'TRUST':5,'RES_ONLY':5,'REGION':2}

'''     'AREAWATER','LINEARWATER','COASTLINE','FACES',
        'FACESAH','FACESAL','FACESMIL','FEATNAMES','PRIMARYROADS',
        'PRISECROADS','RAILS','ROADS'
'''

#note that the original folder pulls did not have Division, Nation, Trust, Res Only, Region as these could not be found...
#on the census site
#character # should be rihgt. SUBMCD was 13, not 18 as listed

new_field = "GISJOIN"
#establish sandbox to work in
arcpy.env.workspace = out_db
#this looks at the (key,item) pairs in the dict
for key, textfield in dir_dict.items():
    #make the key name lowercase in a new variable
    key_lower = key.lower()
    fc = arcpy.ListFeatureClasses("*") 
    fc = fc + key_lower
    print(fc)
'''
    fc_path = out_db + fc[0]
    arcpy.AddField_management(fc_path,new_field,"TEXT","","",textfield,"","","","")
'''

# %% [markdown]
# ## Reprojection

# %%
from glob import glob
import os
import arcpy

# Source location - where are the shapefiles coming from? 
# Change this source location to your source location
# Make sure to copy file paths in using \\ or / as path separators instead of \ (escape key) or use r (raw) to escape 
src = "C:\\Users\\allow001\\work\\scratchdata\\hydro_shp" 

#glob looks for files ending in .shp in the specificed folder location from src (source)
for file in glob(os.path.join(src, "*.shp")):
    #print(file[-19:-17]+'_water_poly.shp')
    #for file in glob(os.path.join(folder,"???_arc.shp")):
        #print(file)
    # input data is in GCS, not projected
    input_features = file
        # output data
    # rename each output - I typically just add "proj" or "projected" to the original name 
    output_feature_class = os.path.join(src,file[-19:-17]+'_water_poly.shp')
    print(output_feature_class)
    # set the Coordinate System - don't change 
    out_coordinate_system = arcpy.SpatialReference('USA Contiguous Albers Equal Area Conic')
    # run the tool
    arcpy.Project_management(input_features, output_feature_class, out_coordinate_system)


# create a spatial reference object for the output coordinate system
#out_coordinate_system = arcpy.SpatialReference('USA Contiguous Albers Equal Area Conic')

# run the tool
#arcpy.Project_management(input_features, output_feature_class, out_coordinate_system)

# %% [markdown]
# ## Water merge

# %%
import os
import sys
import zipfile
import string
import arcpy

#constants
working_directory = "C:/Users/and04671/Documents/Data_Files"
out_db = "C:/Users/and04671/Documents/Data_Files/TIGER2018_water.gdb"
water = 'AREAWATER'

shp_dir = wd + water + "/"
#

arcpy.env.workspace = shp_dir
shps = arcpy.ListFeatureClasses("*")
out_fc = out_db + "tl_2017_us_" + water.lower()
arcpy.Merge_management(shps,out_fc)

# %% [markdown]
# ## Rename Statewide

# %%
# This script renames the state-specific block group feature classes by
# postal abbreviations

import os
import sys
import zipfile
import string
import arcpy

working_directory = r"C:/Users/and04671/Documents/Data_Files"
geodb = working_directory + "TIGER2018_proj_watererase.gdb"
out_fc_stub = "_blck_grp_2018"

state_codes = {
 '53':'WA',
 '10':'DE',
 '11':'DC',
 '55':'WI',
 '54':'WV',
 '15':'HI',
 '12':'FL',
 '56':'WY',
 '72':'PR',
 '34':'NJ',
 '35':'NM',
 '48':'TX',
 '22':'LA',
 '37':'NC',
 '38':'ND',
 '31':'NE',
 '47':'TN',
 '36':'NY',
 '42':'PA',
 '02':'AK',
 '32':'NV',
 '33':'NH',
 '51':'VA',
 '08':'CO',
 '06':'CA',
 '01':'AL',
 '05':'AR',
 '50':'VT',
 '17':'IL',
 '13':'GA',
 '18':'IN',
 '19':'IA',
 '25':'MA',
 '04':'AZ',
 '16':'ID',
 '09':'CT',
 '23':'ME',
 '24':'MD',
 '40':'OK',
 '39':'OH',
 '49':'UT',
 '29':'MO',
 '27':'MN',
 '26':'MI',
 '44':'RI',
 '20':'KS',
 '30':'MT',
 '28':'MS',
 '45':'SC',
 '21':'KY',
 '41':'OR',
 '46':'SD',
 '72':'PR' 
}

arcpy.env.workspace = geodb
fcs = arcpy.ListFeatureClasses("bg_*")

for fc in fcs:
    fc_name = fc.split("_")
    fc_state = fc_name[1]
    state_abbr = state_codes.get(fc_state)
    out_fc = state_abbr + out_fc_stub
    arcpy.Rename_management(fc,out_fc)

# %% [markdown]
# ## Export to SHP .zip

# %%
# This script exports all fcs in a geodb to shapefiles and ZIPS them using the
# NHGIS naming convention

import os
import sys
import glob
import zipfile
import string
import arcpy

working_directory = r"C:/Users/and04671/Documents/Data_Files"
#geodb = wd + "TIGER2018_proj_watererase.gdb"
out_folder = working_directory + "/shps/"

#arcpy.env.workspace = geodb
#fcs = arcpy.ListFeatureClasses("*")

#for fc in fcs:
#    out_shp = fc + ".shp"
#    arcpy.FeatureClassToFeatureClass_conversion(fc,out_folder,out_shp)

os.chdir(out_folder)

shps = glob.glob(out_folder + "*.shp")

ziplist = []

for name in shps:
    file = os.path.basename(name)
    names = file[:-4]
    ziplist.append(names)

for f in ziplist:
    file_name = os.path.join(out_folder,f + ".zip")
    files = glob.glob(str(f)+".*")
    zips = zipfile.ZipFile(file_name,'w')
    for s in files:
        zips.write(s, compress_type = zipfile.ZIP_DEFLATED)
    zips.close()

# %% [markdown]
# ## Rename .zips

# %%
# This script renames shapefiles to lower case 'us' and three character
# fips codes. 

import os
import sys
import glob
import zipfile
import string
#import arcpy

states_upper = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "PR"]

state_codes = {
    'WA': '530',
    'DE': '100',
    'DC': '110',
    'WI': '550',
    'WV': '540',
    'HI': '150',
    'FL': '120',
    'WY': '560',
    'PR': '720',
    'NJ': '340',
    'NM': '350',
    'TX': '480',
    'LA': '220',
    'NC': '370',
    'ND': '380',
    'NE': '310',
    'TN': '470',
    'NY': '360',
    'PA': '420',
    'AK': '020',
    'NV': '320',
    'NH': '330',
    'VA': '510',
    'CO': '080',
    'CA': '060',
    'AL': '010',
    'AR': '050',
    'VT': '500',
    'IL': '170',
    'GA': '130',
    'IN': '180',
    'IA': '190',
    'MA': '250',
    'AZ': '040',
    'ID': '160',
    'CT': '090',
    'ME': '230',
    'MD': '240',
    'OK': '400',
    'OH': '390',
    'UT': '490',
    'MO': '290',
    'MN': '270',
    'MI': '260',
    'RI': '440',
    'KS': '200',
    'MT': '300',
    'MS': '280',
    'SC': '450',
    'KY': '210',
    'OR': '410',
    'SD': '460',
    'PR': '720'
}

SHPwd = "C:/Users/and04671/Documents/Data_Files/shps"

os.chdir(wd)

zips = glob.glob(wd + "US*.zip")

ziplist = []

for name in zips:
    file = os.path.basename(name)
    ziplist.append(file)

for f in ziplist:
    new_zip = f.lower()
    os.rename(f,new_zip)

for state in states_upper:
    in_zip = glob.glob(wd + state + "*.zip")
    in_zip_string = in_zip[0]
    in_zip_file = os.path.basename(in_zip_string)

    out_zip_file = state_codes.get(state) + "_blck_grp_2017.zip"
    os.rename(in_zip_file, out_zip_file)
